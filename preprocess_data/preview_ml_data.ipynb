# %%
import sys
code_dir = "/home/ma-user/work/dataset/dataset_zhh_guiyang/github/MindSpeed-LLM"
sys.path.append(f"{code_dir}")
import numpy as np
import torch
import torch_npu
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoConfig
from megatron.core.datasets.indexed_dataset import IndexedDataset

# %%
data_home = "/home/ma-user/work/dataset/huashan_zhh_guiyang_pfs"
_model_path = f"{data_home}/hf_model/ailab_slm_0_5b/"
# _model_path = f"{data_home}/hf_model/Qwen3-0.6B/"
tokenizer = AutoTokenizer.from_pretrained(_model_path, use_fast=False, trust_remote_code=True)
tokenizer.is_fast
tokenizer_tag = "ailab_slm"  # "qwen3"
seq_len = 4096

# %%
""" pretrain data """
_input_ids_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}/encyclopedia_zh/wiki_ybk_dbk_others/wiki_ybk_dbk_others_text_document"
input_ids_indexed_dataset = IndexedDataset(_input_ids_path, multimodal=False, mmap=True)

# %%
""" sft data """
# _input_ids_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_{seq_len}_pack/MegaScience_nemotron_science__knapsack/MegaScience_nemotron_science_packed_input_ids_document"
# _attention_mask_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_{seq_len}_pack/MegaScience_nemotron_science__knapsack/MegaScience_nemotron_science_packed_attention_mask_document"
# _labels_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_{seq_len}_pack/MegaScience_nemotron_science__knapsack/MegaScience_nemotron_science_packed_labels_document"

_input_ids_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_{seq_len}/MegaScience/MegaScience_packed_input_ids_document"
_attention_mask_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_{seq_len}/MegaScience/MegaScience_packed_attention_mask_document"
_labels_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_{seq_len}/MegaScience/MegaScience_packed_labels_document"

""" rl data """
# _input_ids_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_2048/dapo-math-17k/dapo-math-17k_packed_input_ids_document"
# _attention_mask_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_2048/dapo-math-17k/dapo-math-17k_packed_attention_mask_document"
# _labels_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_2048/dapo-math-17k/dapo-math-17k_packed_labels_document"

""" rerank data """
# _input_ids_path = f"{data_home}/ml_data/ml_data__{tokenizer_tag}_{seq_len}_rerank/train_l2/train_filter_v5_v3_4_2_packed_input_ids_document"


input_ids_indexed_dataset = IndexedDataset(_input_ids_path, multimodal=False, mmap=True)
attention_mask_indexed_dataset = IndexedDataset(_attention_mask_path, multimodal=False, mmap=True)
labels_indexed_dataset = IndexedDataset(_labels_path, multimodal=False, mmap=True)

# %%
""" length of dataset """
len(input_ids_indexed_dataset)

# %%
""" decode input_ids """ 
print(tokenizer.decode(input_ids_indexed_dataset[2333]))

# %%
input_ids_indexed_dataset.document_indices

# %%
input_ids_indexed_dataset.index[0]

# %%
""" print attention_mask """
print([i for i in attention_mask_indexed_dataset[0]])

# %%
""" print sft labels """
print([i for i in labels_indexed_dataset[0]])

# %%
""" print rl labels """
print(tokenizer.decode(labels_indexed_dataset[0]))
